# %%
# coding: utf-8

# naive LSTM model trained with smooth data

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import numpy as np
from torch.autograd import Variable

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
class DecoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        
        self.lstm_1 = nn.LSTM(self.input_size, self.hidden_size)
        self.lstm_2 = nn.LSTM(self.hidden_size, self.hidden_size)
        self.lstm_3 = nn.LSTM(self.hidden_size, self.hidden_size)
        self.lstm_4 = nn.LSTM(self.hidden_size, self.hidden_size)
        self.lstm_5 = nn.LSTM(self.hidden_size, self.hidden_size)
        self.lstm_6 = nn.LSTM(self.hidden_size, self.hidden_size)
        self.lstm_7 = nn.LSTM(self.hidden_size, self.hidden_size)
        
        self.out = nn.Linear(self.hidden_size, self.output_size)
          
        self.softmax = nn.Softmax(dim=1)
        
    def forward(self, input, ch_1, ch_2, ch_3, ch_4, ch_5, ch_6, ch_7):
        (hidden_1, cell_1), (hidden_2, cell_2), (hidden_3, cell_3), (hidden_4, cell_4), (hidden_5, cell_5) = ch_1, ch_2, ch_3, ch_4, ch_5
        (hidden_6, cell_6), (hidden_7, cell_7) = ch_6, ch_7
        
        
        output, (hidden_1, cell_1) = self.lstm_1(input.view(1,1,-1).float(), (hidden_1, cell_1))
        output_1 = output
        
        output, (hidden_2, cell_2) = self.lstm_2(output, (hidden_2, cell_2))
        output_2 = output
        
        output, (hidden_3, cell_3) = self.lstm_3(output + output_1, (hidden_3, cell_3)) # skip_connection 1
        output_3 = output
        
        output, (hidden_4, cell_4) = self.lstm_4(output + output_2, (hidden_4, cell_4)) # skip_connection 2
        output_4 = output
        
        output, (hidden_5, cell_5) = self.lstm_5(output + output_3, (hidden_5, cell_5)) # skip_connection 3
        output_5 = output
        
        output, (hidden_6, cell_6) = self.lstm_6(output + output_4, (hidden_6, cell_6)) # skip_connection 4
        
        output, (hidden_7, cell_7) = self.lstm_7(output + output_5, (hidden_7, cell_7)) # skip_connection 5
        
        output = self.out(output[0])
        #output = self.softmax(output)
        return output, (hidden_1, cell_1),(hidden_2, cell_2),(hidden_3, cell_3),(hidden_4, cell_4),(hidden_5, cell_5),(hidden_6, cell_6),(hidden_7, cell_7)
    
    def init_hidden(self):
        return torch.rand((1, 1, self.hidden_size), device=device)/100
    
    def init_cell(self):
        return torch.rand((1, 1, self.hidden_size), device=device)/100
    
    
print(torch.cuda.is_available())
# Out:
# True

# %%
import pickle

# load data from file

with open("/home/yiqin/2018summer_project/data/smooth_data.pkl", "rb") as f:
    dic = pickle.load(f)
    train_X = dic["X"]
    train_Y = dic["Y"]
    
    
    
target_Tensor = train_Y
maximum_target = len(train_Y)

# %%
def focal_loss(gamma, rescale, criterion, output, target):
    if int(target) == 1:
        p_negative = (1 - output[0,1])**gamma
        loss = rescale * p_negative * criterion(output, target.unsqueeze(0).long())
    else:
        p_negative = (1 - output[0,0])**gamma
        loss = p_negative * criterion(output, target.unsqueeze(0).long())
    return loss


def penalty_loss(penalty, criterion, output, target):
    if int(target) == 1:
        loss = penalty[0] * criterion(output, target)
    else:
        loss = penalty[1] * criterion(output, target)
    return loss

# %%
def train(input_tensor, target_tensor, decoder, decoder_optimizer, criterion, verbose = False, penalty = (3, 1)):
    decoder_optimizer.zero_grad()
    
    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)
    
    hidden_1 = decoder.init_hidden()
    hidden_2 = decoder.init_hidden()
    hidden_3 = decoder.init_hidden()
    hidden_4 = decoder.init_hidden()
    hidden_5 = decoder.init_hidden()
    hidden_6 = decoder.init_hidden()
    hidden_7 = decoder.init_hidden()
    cell_1 = decoder.init_cell()
    cell_2 = decoder.init_cell()
    cell_3 = decoder.init_cell()
    cell_4 = decoder.init_cell()
    cell_5 = decoder.init_cell()
    cell_6 = decoder.init_cell()
    cell_7 = decoder.init_cell()
    
    loss = 0
    
    
    temp = []
    temp_score = []
    
    decoder_input = input_tensor[0]
    
    for di in range(0, target_length):
        decoder_output, (hidden_1, cell_1), (hidden_2, cell_2), (hidden_3, cell_3), (hidden_4, cell_4), (hidden_5, cell_5), (hidden_6, cell_6), (hidden_7, cell_7) = decoder(decoder_input, 
                        (hidden_1, cell_1), (hidden_2, cell_2), (hidden_3, cell_3), (hidden_4, cell_4), (hidden_5, cell_5), (hidden_6, cell_6), (hidden_7, cell_7))
        if verbose:
            output = float(decoder_output.data.cpu().numpy())
            temp.append(str('%.4f'%output))
            #temp_score.append(decoder_output)

        loss += penalty_loss(penalty, criterion, decoder_output.squeeze(0), target_tensor[di].float())
        print(decoder_output.squeeze(0), target_tensor[di].float())
        print("loss:", penalty_loss(penalty, criterion, decoder_output.squeeze(0), target_tensor[di].float()))

        if di + 1 < target_length:
            decoder_input = input_tensor[di + 1]

    loss.backward()

    if verbose:
        print("Prediction :", temp) 
        print("Target:", target_tensor.squeeze())
        #print("Score :", temp_score)
        
    

    decoder_optimizer.step()

    return loss.item() / target_length

# In[63]:

import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))


# In[64]:

def trainIters(decoder, n_iters, print_every = 1000, plot_every = 100, learning_rate = 0.01, total_batch = maximum_target, gamma = 0.1):    
    start = time.time()
    
    plot_losses = []
    print_loss_total = 0
    plot_loss_total = 0
    
    decoder_optimizer = optim.SGD(decoder.parameters(), lr = learning_rate)
    
    criterion = nn.MSELoss()
    
    scheduler = optim.lr_scheduler.StepLR(decoder_optimizer, step_size = total_batch, gamma = gamma)
    
    
    for iter in range(1, n_iters + 1):
        num = iter % total_batch
        verbose = (iter % print_every == 0)
        input_tensor = train_X[num].to(device)
        target_tensor = target_Tensor[num].to(device)
        input_tensor = Variable(input_tensor, requires_grad = True)
        #print(input_tensor.shape, target_tensor.shape)
        if input_tensor.shape[0]<2:
            continue
        if input_tensor.shape[0] != target_tensor.shape[0]:
            continue
        
        loss = train(input_tensor, target_tensor, decoder, 
                     decoder_optimizer, criterion, verbose = verbose)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * print_every, print_loss_avg))
            torch.save(decoder.state_dict(), 'naive_lstm_train.pt')
        
        scheduler.step()

# %%
input_size = 2
hidden_size = 256
output_size = 1

decoder = DecoderRNN(input_size, hidden_size, output_size).to(device)

trainIters(decoder, 100000, print_every=1000, learning_rate=1e-2, gamma=0.2)
# Out:
# tensor(1.00000e-02 *
#        [ 4.7733], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(0.2045, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.4124], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.2385, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.2688], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.2978, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.2194], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(0.2096, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.2021], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(2.7532, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1905], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(0.2099, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1768], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.3360, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1611], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        6.9537, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1458], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        6.9793, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1331], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        7.0004, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1247], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.3578, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1208], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(0.2105, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1213], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(2.7578, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1255], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(0.2104, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1323], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.3546, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1406], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        6.9879, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1498], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        4.4108, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1594], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        4.3704, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1691], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        6.9404, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1786], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.3353, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1877], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(0.2099, device='cuda:0')
# tensor(1.00000e-02 *
#        [ 4.1961], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(2.7535, device='cuda:0')
# tensor([ 0.3602], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.9530, device='cuda:0')
# tensor([ 0.3926], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.0348, device='cuda:0')
# tensor([ 0.4179], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.5787, device='cuda:0')
# tensor([ 0.4375], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1406, device='cuda:0')
# tensor([ 0.4525], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1521, device='cuda:0')
# tensor([ 0.4640], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1612, device='cuda:0')
# tensor([ 0.4725], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1208, device='cuda:0')
# tensor([ 0.4789], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.2377, device='cuda:0')
# tensor([ 0.4835], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        2.7342, device='cuda:0')
# tensor([ 0.4868], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(0.7902, device='cuda:0')
# tensor([ 0.4891], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        1.1931, device='cuda:0')
# tensor([ 0.4907], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.7945, device='cuda:0')
# tensor([ 0.4919], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1346, device='cuda:0')
# tensor([ 0.4928], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1352, device='cuda:0')
# tensor([ 0.4934], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.9233, device='cuda:0')
# tensor([ 0.4938], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-05 *
#        3.8035, device='cuda:0')
# tensor([ 0.4942], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(0.7676, device='cuda:0')
# tensor([ 0.4944], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-05 *
#        3.0838, device='cuda:0')
# tensor([ 0.4945], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.9795, device='cuda:0')
# tensor([ 0.4946], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1366, device='cuda:0')
# tensor([ 0.4947], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1868, device='cuda:0')
# tensor([ 0.4948], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.2149, device='cuda:0')
# tensor([ 0.4948], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.2296, device='cuda:0')
# tensor([ 0.4949], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.2297, device='cuda:0')
# tensor([ 0.4949], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.2150, device='cuda:0')
# tensor([ 0.4949], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1870, device='cuda:0')
# tensor([ 0.4950], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1369, device='cuda:0')
# tensor([ 0.4950], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.0042, device='cuda:0')
# tensor([ 0.4951], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-05 *
#        2.3571, device='cuda:0')
# tensor([ 0.4953], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(0.7642, device='cuda:0')
# tensor([ 0.2964], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.1459, device='cuda:0')
# tensor([ 0.3211], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        5.0554, device='cuda:0')
# tensor([ 0.3406], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.6481, device='cuda:0')
# tensor([ 0.3558], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.6047, device='cuda:0')
# tensor([ 0.3675], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1131, device='cuda:0')
# tensor([ 0.3764], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1191, device='cuda:0')
# tensor([ 0.3829], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1237, device='cuda:0')
# tensor([ 0.3876], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1057, device='cuda:0')
# tensor([ 0.3910], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        7.0762, device='cuda:0')
# tensor([ 0.3935], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.0583, device='cuda:0')
# tensor([ 0.3953], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.0967, device='cuda:0')
# tensor([ 0.3966], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.0921, device='cuda:0')
# tensor([ 0.3976], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.0482, device='cuda:0')
# tensor([ 0.3983], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.1995, device='cuda:0')
# tensor([ 0.3988], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        7.4952, device='cuda:0')
# tensor([ 0.3991], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1133, device='cuda:0')
# tensor([ 0.3993], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1354, device='cuda:0')
# tensor([ 0.3994], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1355, device='cuda:0')
# tensor([ 0.3996], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1136, device='cuda:0')
# tensor([ 0.3998], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        7.5499, device='cuda:0')
# tensor([ 0.4000], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.2488, device='cuda:0')
# tensor([ 0.4001], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        9.9749, device='cuda:0')
# tensor([ 0.4003], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.0791, device='cuda:0')
# tensor([ 0.4004], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        9.9277, device='cuda:0')
# tensor([ 0.4005], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        9.9093, device='cuda:0')
# tensor([ 0.4005], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        9.8927, device='cuda:0')
# tensor([ 0.4006], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.0779, device='cuda:0')
# tensor([ 0.3359], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.6931, device='cuda:0')
# tensor([ 0.3657], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.3391, device='cuda:0')
# tensor([ 0.3893], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.9858, device='cuda:0')
# tensor([ 0.4079], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1193, device='cuda:0')
# tensor([ 0.4224], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1530, device='cuda:0')
# tensor([ 0.4335], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.1746, device='cuda:0')
# tensor([ 0.4418], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.1816, device='cuda:0')
# tensor([ 0.4479], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1736, device='cuda:0')
# tensor([ 0.4524], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1521, device='cuda:0')
# tensor([ 0.4557], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1094, device='cuda:0')
# tensor([ 0.4581], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.3315, device='cuda:0')
# tensor([ 0.4600], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        1.6020, device='cuda:0')
# tensor([ 0.4614], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(0.8702, device='cuda:0')
# tensor([ 0.4625], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        1.4072, device='cuda:0')
# tensor([ 0.4632], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.5451, device='cuda:0')
# tensor([ 0.4636], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1147, device='cuda:0')
# tensor([ 0.4638], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1611, device='cuda:0')
# tensor([ 0.4640], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1612, device='cuda:0')
# tensor([ 0.4640], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1612, device='cuda:0')
# tensor([ 0.4639], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1148, device='cuda:0')
# tensor([ 0.4638], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.5730, device='cuda:0')
# tensor([ 0.4639], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        1.2997, device='cuda:0')
# tensor([ 0.4642], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(0.8613, device='cuda:0')
# tensor([ 0.4644], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        1.2685, device='cuda:0')
# tensor([ 0.4645], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.6013, device='cuda:0')
# tensor([ 0.4645], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1153, device='cuda:0')
# tensor([ 0.4644], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1615, device='cuda:0')
# tensor([ 0.4643], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1875, device='cuda:0')
# tensor([ 0.4642], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1874, device='cuda:0')
# tensor([ 0.4642], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1614, device='cuda:0')
# tensor([ 0.4644], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1152, device='cuda:0')
# tensor([ 0.4646], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.6054, device='cuda:0')
# tensor([ 0.4648], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        1.2374, device='cuda:0')
# tensor([ 0.4650], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(0.8587, device='cuda:0')
# tensor([ 0.2586], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.8257, device='cuda:0')
# tensor([ 0.2790], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        8.4008, device='cuda:0')
# tensor([ 0.2956], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.9093, device='cuda:0')
# tensor([ 0.3090], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        3.3840, device='cuda:0')
# tensor([ 0.3195], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        3.7839, device='cuda:0')
# tensor([ 0.3276], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        6.0266, device='cuda:0')
# tensor([ 0.3337], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.7645, device='cuda:0')
# tensor([ 0.3382], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.3139, device='cuda:0')
# tensor([ 0.3416], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.5098, device='cuda:0')
# tensor([ 0.3441], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        8.8640, device='cuda:0')
# tensor([ 0.3461], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.8893, device='cuda:0')
# tensor([ 0.3476], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.9553, device='cuda:0')
# tensor([ 0.3487], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.0056, device='cuda:0')
# tensor([ 0.3495], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        9.9020, device='cuda:0')
# tensor([ 0.3500], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.2491, device='cuda:0')
# tensor([ 0.3504], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.2658, device='cuda:0')
# tensor([ 0.3507], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.2276, device='cuda:0')
# tensor([ 0.3510], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.0198, device='cuda:0')
# tensor([ 0.3512], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.1161, device='cuda:0')
# tensor([ 0.3514], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.1234, device='cuda:0')
# tensor([ 0.3515], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.1299, device='cuda:0')
# tensor([ 0.3515], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.0309, device='cuda:0')
# tensor([ 0.3515], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.2049, device='cuda:0')
# tensor([ 0.3515], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.2615, device='cuda:0')
# tensor([ 0.3669], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.7705, device='cuda:0')
# tensor([ 0.4007], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.2716, device='cuda:0')
# tensor([ 0.4277], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        9.1639, device='cuda:0')
# tensor([ 0.4492], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1496, device='cuda:0')
# tensor([ 0.4661], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1891, device='cuda:0')
# tensor([ 0.4792], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.2006, device='cuda:0')
# tensor([ 0.4892], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1821, device='cuda:0')
# tensor([ 0.4968], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1383, device='cuda:0')
# tensor([ 0.5026], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.3795, device='cuda:0')
# tensor([ 0.5068], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-05 *
#        4.6618, device='cuda:0')
# tensor([ 0.5099], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(0.7205, device='cuda:0')
# tensor([ 0.5122], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        1.4764, device='cuda:0')
# tensor([ 0.5138], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.9566, device='cuda:0')
# tensor([ 0.5149], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1521, device='cuda:0')
# tensor([ 0.5158], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1527, device='cuda:0')
# tensor([ 0.5165], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1532, device='cuda:0')
# tensor([ 0.5170], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        7.1275, device='cuda:0')
# tensor([ 0.5173], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        3.0095, device='cuda:0')
# tensor([ 0.5176], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(0.6980, device='cuda:0')
# tensor([ 0.5179], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        3.1954, device='cuda:0')
# tensor([ 0.5179], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        7.1780, device='cuda:0')
# tensor([ 0.5180], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1544, device='cuda:0')
# tensor([ 0.5180], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.2075, device='cuda:0')
# tensor([ 0.5181], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.2370, device='cuda:0')
# tensor([ 0.5181], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.2525, device='cuda:0')
# tensor([ 0.5181], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.2525, device='cuda:0')
# tensor([ 0.5181], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.2371, device='cuda:0')
# tensor([ 0.5182], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.2076, device='cuda:0')
# tensor([ 0.5182], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1546, device='cuda:0')
# tensor([ 0.5183], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        7.1960, device='cuda:0')
# tensor([ 0.5184], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        3.3771, device='cuda:0')
# tensor([ 0.5185], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(0.6954, device='cuda:0')
# tensor([ 0.2633], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.6031, device='cuda:0')
# tensor([ 0.2842], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        1.1689, device='cuda:0')
# tensor([ 0.3015], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        3.1165, device='cuda:0')
# tensor([ 0.3157], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.4105, device='cuda:0')
# tensor([ 0.3269], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.7435, device='cuda:0')
# tensor([ 0.3357], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        9.2685, device='cuda:0')
# tensor([ 0.3423], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        9.6763, device='cuda:0')
# tensor([ 0.3472], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.1079, device='cuda:0')
# tensor([ 0.3509], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.1012, device='cuda:0')
# tensor([ 0.3535], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.0719, device='cuda:0')
# tensor([ 0.3555], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.0867, device='cuda:0')
# tensor([ 0.3571], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.2400, device='cuda:0')
# tensor([ 0.3582], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.0104, device='cuda:0')
# tensor([ 0.3590], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.1886, device='cuda:0')
# tensor([ 0.3596], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.5030, device='cuda:0')
# tensor([ 0.3600], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.8480, device='cuda:0')
# tensor([ 0.3602], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1082, device='cuda:0')
# tensor([ 0.3604], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1083, device='cuda:0')
# tensor([ 0.3606], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.8873, device='cuda:0')
# tensor([ 0.3608], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.5619, device='cuda:0')
# tensor([ 0.3611], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.2333, device='cuda:0')
# tensor([ 0.3612], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.9252, device='cuda:0')
# tensor([ 0.3614], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.2234, device='cuda:0')
# tensor([ 0.3615], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.9174, device='cuda:0')
# tensor([ 0.3616], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.9144, device='cuda:0')
# tensor([ 0.3617], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.9117, device='cuda:0')
# tensor([ 0.3618], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.2219, device='cuda:0')
# tensor([ 0.3342], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.7499, device='cuda:0')
# tensor([ 0.3635], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.2886, device='cuda:0')
# tensor([ 0.3874], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.8875, device='cuda:0')
# tensor([ 0.4069], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1186, device='cuda:0')
# tensor([ 0.4223], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1529, device='cuda:0')
# tensor([ 0.4343], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.1753, device='cuda:0')
# tensor([ 0.4435], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.1831, device='cuda:0')
# tensor([ 0.4505], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1757, device='cuda:0')
# tensor([ 0.4556], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1545, device='cuda:0')
# tensor([ 0.4594], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1118, device='cuda:0')
# tensor([ 0.4622], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.5037, device='cuda:0')
# tensor([ 0.4644], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        1.2669, device='cuda:0')
# tensor([ 0.4661], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(0.8550, device='cuda:0')
# tensor([ 0.4674], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        1.0630, device='cuda:0')
# tensor([ 0.4682], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.7633, device='cuda:0')
# tensor([ 0.4688], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1182, device='cuda:0')
# tensor([ 0.4691], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1653, device='cuda:0')
# tensor([ 0.4692], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1654, device='cuda:0')
# tensor([ 0.4692], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1654, device='cuda:0')
# tensor([ 0.4691], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1184, device='cuda:0')
# tensor([ 0.4691], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.8007, device='cuda:0')
# tensor([ 0.4692], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        9.4770, device='cuda:0')
# tensor([ 0.4695], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(0.8444, device='cuda:0')
# tensor([ 0.4697], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        9.1821, device='cuda:0')
# tensor([ 0.4698], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.8327, device='cuda:0')
# tensor([ 0.4699], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1189, device='cuda:0')
# tensor([ 0.4698], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1659, device='cuda:0')
# tensor([ 0.4696], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1922, device='cuda:0')
# tensor([ 0.4695], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1921, device='cuda:0')
# tensor([ 0.4695], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(0.1657, device='cuda:0')
# tensor([ 0.4697], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(0.1188, device='cuda:0')
# tensor([ 0.4699], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.8366, device='cuda:0')
# tensor([ 0.4702], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        8.8965, device='cuda:0')
# tensor([ 0.4704], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(0.8415, device='cuda:0')
# tensor([ 0.2520], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.1498, device='cuda:0')
# tensor([ 0.2721], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        4.9015, device='cuda:0')
# tensor([ 0.2892], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.6975, device='cuda:0')
# tensor([ 0.3034], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.8051, device='cuda:0')
# tensor([ 0.3150], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.0518, device='cuda:0')
# tensor([ 0.3242], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.5822, device='cuda:0')
# tensor([ 0.3313], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        9.0052, device='cuda:0')
# tensor([ 0.3367], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        7.5211, device='cuda:0')
# tensor([ 0.3408], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.6573, device='cuda:0')
# tensor([ 0.3438], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        8.8012, device='cuda:0')
# tensor([ 0.3460], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.3702, device='cuda:0')
# tensor([ 0.3476], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.2767, device='cuda:0')
# tensor([ 0.3488], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.2850, device='cuda:0')
# tensor([ 0.3498], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        9.9528, device='cuda:0')
# tensor([ 0.3505], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.0851, device='cuda:0')
# tensor([ 0.3510], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.3238, device='cuda:0')
# tensor([ 0.3514], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1025, device='cuda:0')
# tensor([ 0.3518], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.1130, device='cuda:0')
# tensor([ 0.3520], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.1132, device='cuda:0')
# tensor([ 0.3522], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1030, device='cuda:0')
# tensor([ 0.3524], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.4029, device='cuda:0')
# tensor([ 0.3525], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.1756, device='cuda:0')
# tensor([ 0.3526], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.0531, device='cuda:0')
# tensor([ 0.3527], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.1697, device='cuda:0')
# tensor([ 0.3528], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.2567, device='cuda:0')
# tensor([ 0.3528], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.1661, device='cuda:0')
# tensor([ 0.3529], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.0588, device='cuda:0')
# tensor([ 0.3530], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.1977, device='cuda:0')
# tensor([ 0.3530], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.4390, device='cuda:0')
# tensor([ 0.3530], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1035, device='cuda:0')
# tensor([ 0.3531], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1036, device='cuda:0')
# tensor([ 0.3531], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1036, device='cuda:0')
# tensor([ 0.3531], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.4469, device='cuda:0')
# tensor([ 0.3531], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.2047, device='cuda:0')
# tensor([ 0.3531], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.0635, device='cuda:0')
# tensor([ 0.3531], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.1573, device='cuda:0')
# tensor([ 0.3531], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.2555, device='cuda:0')
# tensor([ 0.2562], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.9458, device='cuda:0')
# tensor([ 0.2769], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-04 *
#        7.2435, device='cuda:0')
# tensor([ 0.2947], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.8808, device='cuda:0')
# tensor([ 0.3097], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.1118, device='cuda:0')
# tensor([ 0.3220], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.4534, device='cuda:0')
# tensor([ 0.3318], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        9.9944, device='cuda:0')
# tensor([ 0.3393], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.1048, device='cuda:0')
# tensor([ 0.3451], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        9.8490, device='cuda:0')
# tensor([ 0.3494], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.2310, device='cuda:0')
# tensor([ 0.3526], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.1809, device='cuda:0')
# tensor([ 0.3550], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.1031, device='cuda:0')
# tensor([ 0.3568], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        2.0508, device='cuda:0')
# tensor([ 0.3581], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.2361, device='cuda:0')
# tensor([ 0.3591], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.9851, device='cuda:0')
# tensor([ 0.3599], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.2081, device='cuda:0')
# tensor([ 0.3606], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.5496, device='cuda:0')
# tensor([ 0.3612], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.9193, device='cuda:0')
# tensor([ 0.3616], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1091, device='cuda:0')
# tensor([ 0.3620], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.1200, device='cuda:0')
# tensor([ 0.3622], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.1201, device='cuda:0')
# tensor([ 0.3624], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.1203, device='cuda:0')
# tensor([ 0.3625], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1097, device='cuda:0')
# tensor([ 0.3625], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        9.0012, device='cuda:0')
# tensor([ 0.3625], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.6387, device='cuda:0')
# tensor([ 0.3625], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.2646, device='cuda:0')
# tensor([ 0.3625], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.8902, device='cuda:0')
# tensor([ 0.3626], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.2189, device='cuda:0')
# tensor([ 0.3626], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.8865, device='cuda:0')
# tensor([ 0.3627], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.2700, device='cuda:0')
# tensor([ 0.3627], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.6522, device='cuda:0')
# tensor([ 0.3628], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        9.0190, device='cuda:0')
# tensor([ 0.3629], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1100, device='cuda:0')
# tensor([ 0.3630], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.1207, device='cuda:0')
# tensor([ 0.3630], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(0.1207, device='cuda:0')
# tensor([ 0.3630], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(0.1101, device='cuda:0')
# tensor([ 0.3630], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        9.0312, device='cuda:0')
# tensor([ 0.3630], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        5.6660, device='cuda:0')
# tensor([ 0.3631], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.2781, device='cuda:0')
# tensor([ 0.3631], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.8744, device='cuda:0')
# tensor([ 0.3632], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.2167, device='cuda:0')
# tensor([ 0.2257], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        7.5255, device='cuda:0')
# tensor([ 0.2429], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-05 *
#        5.0796, device='cuda:0')
# tensor([ 0.2581], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        1.7709, device='cuda:0')
# tensor([ 0.2711], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        4.3531, device='cuda:0')
# tensor([ 0.2820], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.2869, device='cuda:0')
# tensor([ 0.2907], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        7.5664, device='cuda:0')
# tensor([ 0.2975], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        7.9475, device='cuda:0')
# tensor([ 0.3028], device='cuda:0') tensor(1.00000e-02 *
#        1.5625, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.2465, device='cuda:0')
# tensor([ 0.3068], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        7.5901, device='cuda:0')
# tensor([ 0.3097], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.1100, device='cuda:0')
# tensor([ 0.3118], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        3.4898, device='cuda:0')
# tensor([ 0.3134], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        4.0240, device='cuda:0')
# tensor([ 0.3147], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        3.4335, device='cuda:0')
# tensor([ 0.3157], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.4049, device='cuda:0')
# tensor([ 0.3164], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        3.3702, device='cuda:0')
# tensor([ 0.3170], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        4.4863, device='cuda:0')
# tensor([ 0.3174], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        3.7027, device='cuda:0')
# tensor([ 0.3178], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.5177, device='cuda:0')
# tensor([ 0.3181], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.5340, device='cuda:0')
# tensor([ 0.3184], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        3.7389, device='cuda:0')
# tensor([ 0.3185], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        4.6968, device='cuda:0')
# tensor([ 0.3186], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        3.2896, device='cuda:0')
# tensor([ 0.3187], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.3926, device='cuda:0')
# tensor([ 0.3187], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        3.2853, device='cuda:0')
# tensor([ 0.3188], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        4.7351, device='cuda:0')
# tensor([ 0.3189], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        3.7594, device='cuda:0')
# tensor([ 0.3189], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.5741, device='cuda:0')
# tensor([ 0.3189], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.2758, device='cuda:0')
# tensor([ 0.3190], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.2783, device='cuda:0')
# tensor([ 0.3190], device='cuda:0') tensor(1.00000e-02 *
#        3.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        8.2804, device='cuda:0')
# tensor([ 0.3190], device='cuda:0') tensor(1.00000e-02 *
#        6.2500, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        6.5800, device='cuda:0')
# tensor([ 0.3190], device='cuda:0') tensor(0.1250, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        3.7643, device='cuda:0')
# tensor([ 0.3190], device='cuda:0') tensor(0.2500, device='cuda:0')
# loss: tensor(1.00000e-03 *
#        4.7622, device='cuda:0')
# tensor([ 0.3190], device='cuda:0') tensor(0.5000, device='cuda:0')
# loss: tensor(1.00000e-02 *
#        3.2759, device='cuda:0')
# tensor([ 0.3190], device='cuda:0') tensor(1., device='cuda:0')
# loss: tensor(1.3914, device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-060320bc2c86> in <module>()
#       5 decoder = DecoderRNN(input_size, hidden_size, output_size).to(device)
#       6
# ----> 7 trainIters(decoder, 100000, print_every=1000, learning_rate=1e-2, gamma=0.2)
#       8
#
# <ipython-input-15-610521246b2f> in trainIters(decoder, n_iters, print_every, plot_every, learning_rate, total_batch, gamma)
#     105
#     106         loss = train(input_tensor, target_tensor, decoder,
# --> 107                      decoder_optimizer, criterion, verbose = verbose)
#     108         print_loss_total += loss
#     109         plot_loss_total += loss
#
# <ipython-input-15-610521246b2f> in train(input_tensor, target_tensor, decoder, decoder_optimizer, criterion, verbose, penalty)
#      43             decoder_input = input_tensor[di + 1]
#      44
# ---> 45     loss.backward()
#      46
#      47     if verbose:
#
# /home/yiqin/anaconda3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# /home/yiqin/anaconda3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:
